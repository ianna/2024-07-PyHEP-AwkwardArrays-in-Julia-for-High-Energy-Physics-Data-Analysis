# %%
import awkward as ak
from juliacall import Main as jl

jl.seval("using AwkwardArray")
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
jl.seval("using Pkg")
jl.seval("Pkg.add(\"UnROOT\")")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed IrrationalConstants ── v0.2.2
#    Installed Calculus ───────────── v0.5.1
#    Installed Crayons ────────────── v4.1.1
#    Installed LRUCache ───────────── v1.6.1
#    Installed ColorTypes ─────────── v0.11.5
#    Installed PrettyTables ───────── v2.3.2
#    Installed CodecXz ────────────── v0.7.2
#    Installed XRootD_cxxwrap_jll ─── v0.1.0+0
#    Installed XML2_jll ───────────── v2.13.1+0
#    Installed Zstd_jll ───────────── v1.5.6+0
#    Installed LoggingExtras ──────── v1.0.3
#    Installed IterTools ──────────── v1.10.0
#    Installed BitFlags ───────────── v0.1.9
#    Installed SimpleBufferStream ─── v1.1.0
#    Installed IntervalSets ───────── v0.7.10
#    Installed FHist ──────────────── v0.11.5
#    Installed libxcrypt_legacy_jll ─ v4.4.28+0
#    Installed SentinelArrays ─────── v1.4.3
#    Installed OpenSSL_jll ────────── v1.1.23+0
#    Installed GeometryBasics ─────── v0.4.11
#    Installed XZ_jll ─────────────── v5.4.6+0
#    Installed JSON_C_jll ─────────── v0.15.0+0
#    Installed MakieCore ──────────── v0.8.3
#    Installed FixedPointNumbers ──── v0.8.5
#    Installed RecipesBase ────────── v1.3.4
#    Installed CxxWrap ────────────── v0.14.2
#    Installed Mixers ─────────────── v0.1.2
#    Installed Extents ────────────── v0.1.3
#    Installed StaticArrays ───────── v1.9.6
#    Installed ConcurrentUtilities ── v2.4.1
#    Installed UnROOT ─────────────── v0.10.31
#    Installed XXHashNative ───────── v1.0.1
#    Installed StaticArraysCore ───── v1.4.3
#    Installed ConstructionBase ───── v1.5.5
#    Installed URIs ───────────────── v1.5.1
#    Installed Libiconv_jll ───────── v1.17.0+0
#    Installed EarCut_jll ─────────── v2.2.4+0
#    Installed AbstractTrees ──────── v0.4.5
#    Installed LaTeXStrings ───────── v1.3.1
#    Installed TranscodingStreams ─── v0.10.10
#    Installed Measurements ───────── v2.11.0
#    Installed StructArrays ───────── v0.6.18
#    Installed XRootD ─────────────── v0.1.0
#    Installed OpenSSL ────────────── v1.4.3
#    Installed BitIntegers ────────── v0.3.1
#    Installed Reexport ───────────── v1.2.2
#    Installed LorentzVectors ─────── v0.4.3
#    Installed HTTP ───────────────── v1.10.8
#    Installed MbedTLS ────────────── v1.1.9
#    Installed Lz4_jll ────────────── v1.9.4+0
#    Installed CodecZstd ──────────── v0.8.3
#    Installed libcxxwrap_julia_jll ─ v0.11.2+1
#    Installed LogExpFunctions ────── v0.3.28
#    Installed DataStructures ─────── v0.18.20
#    Installed ArraysOfArrays ─────── v0.6.5
#    Installed XRootD_jll ─────────── v5.6.9+0
#    Installed StatsAPI ───────────── v1.7.0
#    Installed Memoization ────────── v0.2.1
#    Installed Observables ────────── v0.5.5
#    Installed GeoInterface ───────── v1.3.5
#    Installed Compat ─────────────── v4.15.0
#    Installed UnPack ─────────────── v1.0.2
#    Installed Parameters ─────────── v0.12.3
#    Installed CodecLz4 ───────────── v0.4.3
#    Installed Libuuid_jll ────────── v2.40.1+0
#    Installed LibDeflate ─────────── v0.4.2
#    Installed libdeflate_jll ─────── v1.20.0+0
#    Installed CodecZlib ──────────── v0.7.4
#    Installed Missings ───────────── v1.2.0
#    Installed StringManipulation ─── v0.3.4
#    Installed DocStringExtensions ── v0.9.3
#    Installed StatsBase ──────────── v0.34.3
#    Installed ExceptionUnwrapping ── v0.1.10
#    Installed SortingAlgorithms ──── v1.2.1
#    Installed BayesHistogram ─────── v1.0.7
#     Updating `~/.julia/environments/pyjuliapkg/Project.toml`
#   [3cd96dde] + UnROOT v0.10.31
#     Updating `~/.julia/environments/pyjuliapkg/Manifest.toml`
#   [1520ce14] + AbstractTrees v0.4.5
#   [65a8f2f4] + ArraysOfArrays v0.6.5
#   [000d9b38] + BayesHistogram v1.0.7
#   [d1d4a3ce] + BitFlags v0.1.9
#   [c3b6d118] + BitIntegers v0.3.1
#   [49dc2e85] + Calculus v0.5.1
#   [5ba52731] + CodecLz4 v0.4.3
#   [ba30903b] + CodecXz v0.7.2
#   [944b1d66] + CodecZlib v0.7.4
#   [6b39b394] + CodecZstd v0.8.3
#   [3da002f7] + ColorTypes v0.11.5
#   [34da2185] + Compat v4.15.0
#   [f0e56b4a] + ConcurrentUtilities v2.4.1
#   [187b0558] + ConstructionBase v1.5.5
#   [a8cc5b0e] + Crayons v4.1.1
# ⌅ [1f15a43c] + CxxWrap v0.14.2
#   [864edb3b] + DataStructures v0.18.20
#   [ffbed154] + DocStringExtensions v0.9.3
#   [460bff9d] + ExceptionUnwrapping v0.1.10
#   [411431e0] + Extents v0.1.3
#   [68837c9b] + FHist v0.11.5
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [cf35fbd7] + GeoInterface v1.3.5
#   [5c1252a2] + GeometryBasics v0.4.11
#   [cd3eb016] + HTTP v1.10.8
#   [8197267c] + IntervalSets v0.7.10
#   [92d709cd] + IrrationalConstants v0.2.2
#   [c8e1da08] + IterTools v1.10.0
#   [8ac3fa9e] + LRUCache v1.6.1
#   [b964fa9f] + LaTeXStrings v1.3.1
#   [9255714d] + LibDeflate v0.4.2
#   [2ab3a3ac] + LogExpFunctions v0.3.28
#   [e6f89c97] + LoggingExtras v1.0.3
#   [3f54b04b] + LorentzVectors v0.4.3
#   [20f20a25] + MakieCore v0.8.3
#   [739be429] + MbedTLS v1.1.9
#   [eff96d63] + Measurements v2.11.0
#   [6fafb56a] + Memoization v0.2.1
#   [e1d29d7a] + Missings v1.2.0
#   [2a8e4939] + Mixers v0.1.2
#   [510215fc] + Observables v0.5.5
#   [4d8831e6] + OpenSSL v1.4.3
#   [d96e819e] + Parameters v0.12.3
#   [08abe8d2] + PrettyTables v2.3.2
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [189a3867] + Reexport v1.2.2
#   [91c51154] + SentinelArrays v1.4.3
#   [777ac1f9] + SimpleBufferStream v1.1.0
#   [a2af1166] + SortingAlgorithms v1.2.1
#   [90137ffa] + StaticArrays v1.9.6
#   [1e83bf80] + StaticArraysCore v1.4.3
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.3
#   [892a3eda] + StringManipulation v0.3.4
#   [09ab397b] + StructArrays v0.6.18
#   [3bb67fe8] + TranscodingStreams v0.10.10
#   [5c2747f8] + URIs v1.5.1
#   [3a884ed6] + UnPack v1.0.2
#   [3cd96dde] + UnROOT v0.10.31
#   [164e3b87] + XRootD v0.1.0
#   [e5d8e439] + XXHashNative v1.0.1
#   [5ae413db] + EarCut_jll v2.2.4+0
#   [9cdfc4e7] + JSON_C_jll v0.15.0+0
#   [94ce4f54] + Libiconv_jll v1.17.0+0
#   [38a345b3] + Libuuid_jll v2.40.1+0
#   [5ced341a] + Lz4_jll v1.9.4+0
# ⌅ [458c3c95] + OpenSSL_jll v1.1.23+0
#   [02c8fc9c] + XML2_jll v2.13.1+0
#   [bb14ce0c] + XRootD_cxxwrap_jll v0.1.0+0
#   [b6113df7] + XRootD_jll v5.6.9+0
#   [ffd25f8a] + XZ_jll v5.4.6+0
#   [3161d3a3] + Zstd_jll v1.5.6+0
# ⌅ [3eaa8342] + libcxxwrap_julia_jll v0.11.2+1
#   [46979653] + libdeflate_jll v1.20.0+0
#   [5ef642bb] + libxcrypt_legacy_jll v4.4.28+0
#   [2f01184e] + SparseArrays v1.10.0
#   [10745b16] + Statistics v1.10.0
#   [bea87d4a] + SuiteSparse_jll v7.2.1+1
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ UnPack
#   ✓ Reexport
#   ✓ LorentzVectors
#   ✓ LaTeXStrings
#   ✓ LRUCache
#   ✓ Observables
#   ✓ ConstructionBase
#   ✓ Compat
#   ✓ IntervalSets
#   ✓ DocStringExtensions
#   ✓ AbstractTrees
#   ✓ Calculus
#   ✓ StatsAPI
#   ✓ SimpleBufferStream
#   ✓ JSON_C_jll
#   ✓ BitFlags
#   ✓ MbedTLS
#   ✓ URIs
#   ✓ Memoization
#   ✓ IrrationalConstants
#   ✓ LoggingExtras
#   ✓ ExceptionUnwrapping
#   ✓ IterTools
#   ✓ Extents
#   ✓ BitIntegers
#   ✓ StaticArraysCore
#   ✓ ConcurrentUtilities
#   ✓ SentinelArrays
#   ✓ BayesHistogram
#   ✓ TranscodingStreams
#   ✓ Missings
#   ✓ Mixers
#   ✓ Crayons
#   ✓ EarCut_jll
#   ✓ OpenSSL_jll
#   ✓ libdeflate_jll
#   ✓ XZ_jll
#   ✓ Zstd_jll
#   ✓ Statistics
#   ✓ libxcrypt_legacy_jll
#   ✓ Libiconv_jll
#   ✓ LRUCache → SerializationExt
#   ✓ Compat → CompatLinearAlgebraExt
#   ✓ Parameters
#   ✓ Lz4_jll
#   ✓ Libuuid_jll
#   ✓ libcxxwrap_julia_jll
#   ✓ TranscodingStreams → TestExt
#   ✓ LogExpFunctions
#   ✓ Measurements
#   ✓ RecipesBase
#   ✓ XML2_jll
#   ✓ StringManipulation
#   ✓ LibDeflate
#   ✓ GeoInterface
#   ✓ CodecXz
#   ✓ CodecZlib
#   ✓ ArraysOfArrays
#   ✓ Measurements → MeasurementsRecipesBaseExt
#   ✓ CodecLz4
#   ✓ ArraysOfArrays → ArraysOfArraysStaticArraysCoreExt
#   ✓ IntervalSets → IntervalSetsRecipesBaseExt
#   ✓ CodecZstd
#   ✓ OpenSSL
#   ✓ DataStructures
#   ✓ IntervalSets → IntervalSetsRandomExt
#   ✓ XRootD_jll
#   ✓ FixedPointNumbers
#   ✓ SortingAlgorithms
#   ✓ IntervalSets → IntervalSetsStatisticsExt
#   ✓ XRootD_cxxwrap_jll
#   ✓ StatsBase
#   ✓ HTTP
#   ✓ ColorTypes
#   ✓ StaticArrays
#   ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#   ✓ StaticArrays → StaticArraysStatisticsExt
#   ✓ ConstructionBase → ConstructionBaseIntervalSetsExt
#   ✓ XXHashNative
#   ✓ StructArrays
#   ✓ StructArrays → StructArraysStaticArraysExt
#   ✓ StructArrays → StructArraysSparseArraysExt
#   ✓ CxxWrap
#   ✓ PrettyTables
#   ✓ GeometryBasics
#   ✓ XRootD
#   ✓ MakieCore
#   ✓ FHist
#   ✓ UnROOT
#   89 dependencies successfully precompiled in 32 seconds. 31 already precompiled.
